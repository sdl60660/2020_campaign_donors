# %%
import requests
import pandas as pd
import numpy as np
import json

from collections import Counter

# %%
# candidate = 'Yang'

def load_and_process_candidate_data(candidate_name):
    contributions = pd.read_csv('candidate_data/{}-2017-2018.csv'.format(candidate))

    is_individual = contributions['entity_type_desc']=='INDIVIDUAL'
    contributions = contributions[is_individual]
    contributions.head(10)

    contributions['contributor_compound_key'] = contributions[['contributor_name', 'contributor_street_1']].apply(lambda x : '{} {}'.format(x[0],x[1]), axis=1)
    contributions['Full_City'] = contributions[['contributor_city', 'contributor_state']].apply(lambda x : '{}, {}'.format(x[0],x[1]), axis=1)
    contributions['formatted_zip'] = contributions['contributor_zip'].apply(str).str.slice(0,5)

    print(contributions['contributor_compound_key'].nunique())
    return contributions

# %%
# Fuzzy Search

cities = pd.read_csv('data/uscities.csv', encoding="ISO-8859-1")
zipcodes = pd.read_csv('data/uszips.csv', encoding="ISO-8859-1")

def find_county_by_city(city):   
        try:
            index = cities.index[cities['contribution_data_format'] == city][0]
            return cities.get_value(index, 'county_name')
        except IndexError:
            return None

def find_county_by_zip(zipcode):

    try:
        index = zipcodes.index[zipcodes['zip'] == int(zipcode)][0]
        return zipcodes.get_value(index, 'county_name')
    except IndexError:
        return None
    except ValueError:
        return None

def find_county(city, zipcode, city_dict, zipcode_dict):

    if city in ny_dict.keys():
        return ny_dict[city]

    try:
        return zipcode_dict[str(int(zipcode))]

    except:
        if city_dict[city] != None:
            return city_dict[city]
        else:
            return None

ny_dict = {
    'QUEENS, NY': 'Queens',
    'BROOKLYN, NY': 'Kings',
    'MANHATTAN, NY': 'New York',
    'STATEN ISLAND, NY': 'Richmond',
    'BRONX, NY': 'Bronx'
}


def encode_counties(contributions, candidate):
    
    with open('data/city_county_dict.json', 'r') as f:
        city_county_dict = json.load(f)

    with open('data/zip_county_dict.json', 'r') as f:
        zip_county_dict = json.load(f)

    unique_cities = list(contributions.Full_City.unique())
    unique_zipcodes = list(contributions.formatted_zip.unique())

    for city in unique_cities:
        if city not in city_county_dict.keys(): 
            city_county_dict[city] = find_county_by_city(city)

    for zipcode in unique_zipcodes:
            try:
                if str(int(zipcode)) not in zip_county_dict.keys():
                    zip_county_dict[str(int(zipcode))] = find_county_by_zip(zipcode)
            except ValueError:
                pass

#     print('Finished Constructing County Dicts')

    contributions['County'] = contributions[['Full_City', 'formatted_zip']].apply(lambda x: find_county(x[0], x[1], city_county_dict, zip_county_dict), axis=1)
    contributions.to_csv('data/{}_Counties.csv'.format(candidate))
    
    with open('data/city_county_dict.json', 'w') as f:
        city_county_dict = json.dump(city_county_dict, f)

    with open('data/zip_county_dict.json', 'w') as f:
        zip_county_dict = json.dump(zip_county_dict, f)

    return contributions

# %%
# by_county = contributions.groupby(['County'])['contribution_receipt_amount'].sum().reset_index()
# by_county.sort_values(['contribution_receipt_amount'])

# %%
with open('data/state_id_codes.json', 'r') as f:
    state_codes = json.load(f)
    
def get_county_counts(contributions):

#     contributions = pd.read_csv('data/{}_Counties.csv'.format(candidate))

    contributions['Encoded_County'] = contributions[['County', 'contributor_state']].apply(lambda x : '{} - {} - {}'.format(state_codes[x[1]],x[0],x[1]) if x[1] in state_codes.keys() else None, axis=1)

    out_dict = Counter([x for x in list(contributions['Encoded_County']) if x != None and ' - nan - ' not in x])
    return out_dict

# %%
with open('data/state_id_codes.json', 'r') as f:
    state_codes = json.load(f)

def get_county_funding(contributions):
    contributions['County_State'] = contributions[["County", "contributor_state"]].apply(lambda x: '{} - {} - {}'.format(state_codes[x[1]], x[0], x[1]) if x[1] in state_codes.keys() else None, axis=1)    
    
    funds = contributions.groupby("County_State").sum()[['contribution_receipt_amount']]
    funds = funds.reset_index()
    funds['County'] = funds[['County_State']].apply(lambda x: x[0].split(' - ')[1], axis=1)
    funds['State'] = funds[['County_State']].apply(lambda x: x[0].split(' - ')[2], axis=1)
    funds = funds.set_index('County_State')
    return funds[['County', 'State', 'contribution_receipt_amount']]
# Out:
# {'Alameda - CA': 3200.0,
#  'Alexandria (city) - VA': 1000.0,
#  'Anne Arundel - MD': 500.0,
#  'Arlington - VA': 2000.0,
#  'Bexar - TX': 81300.0,
#  'Dallas - TX': 1000.0,
#  'Denver - CO': 300.0,
#  'District of Columbia - DC': 6950.0,
#  'Harris - TX': 42875.0,
#  'Hidalgo - TX': 2700.0,
#  'Kings - NY': 500.0,
#  'Marin - CA': 250.0,
#  'Montgomery - MD': 1000.0,
#  'Montgomery - TX': 2700.0,
#  'New York - NY': 1000.0,
#  'None - TX': 5400.0,
#  'Orange - CA': 2700.0,
#  'Orleans - LA': 2700.0,
#  'Pulaski - AR': 250.0,
#  'San Francisco - CA': 1000.0,
#  'San Mateo - CA': 6900.0,
#  'Santa Clara - CA': 250.0,
#  'Travis - TX': 25550.0}

# %%
out_dict = {}
meta_data = {}
candidates = ['Trump', 'Yang', 'Delaney', 'Castro']

for candidate in candidates:
    meta_data[candidate] = {}

    contributions = load_and_process_candidate_data(candidate)
    contributions = encode_counties(contributions, candidate)
    
    county_counts = get_county_counts(contributions)
    county_fundraising = get_county_funding(contributions)
    
    top_counties = county_fundraising.sort_values(['contribution_receipt_amount'], ascending=False)
    top_states = county_fundraising.groupby(['State']).sum().sort_values(['contribution_receipt_amount'], ascending=False).to_dict()
    
    meta_data[candidate]['Counties'] = {' - '.join(k.split(' - ')[1:]): v for k,v in (a.sort_values(['contribution_receipt_amount'], ascending=False).to_dict()['contribution_receipt_amount']).items()}
    meta_data[candidate]['States'] = top_states['contribution_receipt_amount']
    
    for k, v in county_counts.items():
        if k in out_dict.keys():
            out_dict[k]['Count'][candidate] = v
            out_dict[k]['Fundraising'][candidate] = county_fundraising.loc[k, 'contribution_receipt_amount']
        else:
            out_dict[k] = {'Count': {candidate: v}, 'Fundraising': {candidate: county_fundraising.loc[k, 'contribution_receipt_amount']}, 'State_ID': k.split(' - ')[0], 'County': k.split(' - ')[1], 'State': k.split(' - ')[2]}

for k, v in out_dict.items():
    for candidate in candidates:
        if candidate not in v['Count'].keys():
            v['Count'][candidate] = 0
        if candidate not in v['Fundraising'].keys():
            v['Fundraising'][candidate] = 0.0

with open('processed_data/new_county_counts.json', 'w') as f:
    json.dump(out_dict, f)

with oepn('processed_data/candidate_meta_data.json', 'w') as f:
    json.dump(meta_data, f)

out_dict
# Out:
# /Users/samlearner/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (5,11,26,27,35,36,37,38,42,43,44,45,54,65,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# 92741
# 2364
# 795
# 113
# {'48 - Williamson - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 767,
#    'Yang': 1},
#   'County': 'Williamson',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 46561.790000000015,
#    'Yang': 1.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '13 - DeKalb - GA': {'Count': {'Castro': 0,
#    'Delaney': 3,
#    'Trump': 422,
#    'Yang': 5},
#   'County': 'DeKalb',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 1500.0,
#    'Trump': 17756.03,
#    'Yang': 90.0},
#   'State': 'GA',
#   'State_ID': '13'},
#  '27 - St. Louis - MN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 126,
#    'Yang': 1},
#   'County': 'St. Louis',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 7816.81,
#    'Yang': 20.0},
#   'State': 'MN',
#   'State_ID': '27'},
#  '47 - Davidson - TN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 1078,
#    'Yang': 8},
#   'County': 'Davidson',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 79248.52999999998,
#    'Yang': 53.0},
#   'State': 'TN',
#   'State_ID': '47'},
#  '28 - Washington - MS': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 15,
#    'Yang': 0},
#   'County': 'Washington',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 1924.1300000000003,
#    'Yang': 0.0},
#   'State': 'MS',
#   'State_ID': '28'},
#  '48 - Bexar - TX': {'Count': {'Castro': 48,
#    'Delaney': 0,
#    'Trump': 2636,
#    'Yang': 14},
#   'County': 'Bexar',
#   'Fundraising': {'Castro': 81300.0,
#    'Delaney': 0.0,
#    'Trump': 271192.43000000017,
#    'Yang': 384.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '48 - Harris - TX': {'Count': {'Castro': 23,
#    'Delaney': 1,
#    'Trump': 4991,
#    'Yang': 12},
#   'County': 'Harris',
#   'Fundraising': {'Castro': 42875.0,
#    'Delaney': 1000.0,
#    'Trump': 508392.0299999998,
#    'Yang': 878.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '06 - Riverside - CA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 2664,
#    'Yang': 12},
#   'County': 'Riverside',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 150988.25999999998,
#    'Yang': 88.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '32 - Washoe - NV': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 984,
#    'Yang': 7},
#   'County': 'Washoe',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 90138.54000000001,
#    'Yang': 51.0},
#   'State': 'NV',
#   'State_ID': '32'},
#  '26 - Oakland - MI': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 1380,
#    'Yang': 12},
#   'County': 'Oakland',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 2000.0,
#    'Trump': 113325.51000000004,
#    'Yang': 66.0},
#   'State': 'MI',
#   'State_ID': '26'},
#  '06 - Sonoma - CA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 436,
#    'Yang': 14},
#   'County': 'Sonoma',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 23300.58,
#    'Yang': 401.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '40 - Ottawa - OK': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 24,
#    'Yang': 0},
#   'County': 'Ottawa',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 1123.5, 'Yang': 0.0},
#   'State': 'OK',
#   'State_ID': '40'},
#  '39 - Clinton - OH': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 33,
#    'Yang': 0},
#   'County': 'Clinton',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 1761.6800000000003,
#    'Yang': 0.0},
#   'State': 'OH',
#   'State_ID': '39'},
#  '04 - Maricopa - AZ': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 5953,
#    'Yang': 31},
#   'County': 'Maricopa',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 475483.0699999994,
#    'Yang': 363.0},
#   'State': 'AZ',
#   'State_ID': '04'},
#  '31 - Douglas - NE': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 514,
#    'Yang': 3},
#   'County': 'Douglas',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 34655.98,
#    'Yang': 41.0},
#   'State': 'NE',
#   'State_ID': '31'},
#  '48 - Lampasas - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 109,
#    'Yang': 0},
#   'County': 'Lampasas',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 6918.75,
#    'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '48 - Grayson - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 255,
#    'Yang': 1},
#   'County': 'Grayson',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 18190.47,
#    'Yang': 1.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '12 - Charlotte - FL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 219,
#    'Yang': 1},
#   'County': 'Charlotte',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 10442.810000000001,
#    'Yang': 1.0},
#   'State': 'FL',
#   'State_ID': '12'},
#  '05 - Benton - AR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 346,
#    'Yang': 1},
#   'County': 'Benton',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 22383.329999999998,
#    'Yang': 5.0},
#   'State': 'AR',
#   'State_ID': '05'},
#  '24 - Montgomery - MD': {'Count': {'Castro': 1,
#    'Delaney': 346,
#    'Trump': 1086,
#    'Yang': 18},
#   'County': 'Montgomery',
#   'Fundraising': {'Castro': 1000.0,
#    'Delaney': 373809.6000000001,
#    'Trump': 81120.16000000002,
#    'Yang': 296.0},
#   'State': 'MD',
#   'State_ID': '24'},
#  '04 - Pima - AZ': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 1223,
#    'Yang': 8},
#   'County': 'Pima',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 70597.08000000002,
#    'Yang': 89.0},
#   'State': 'AZ',
#   'State_ID': '04'},
#  '53 - Douglas - WA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 20,
#    'Yang': 0},
#   'County': 'Douglas',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 657.5, 'Yang': 0.0},
#   'State': 'WA',
#   'State_ID': '53'},
#  '18 - Elkhart - IN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 169,
#    'Yang': 0},
#   'County': 'Elkhart',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 23238.37,
#    'Yang': 0.0},
#   'State': 'IN',
#   'State_ID': '18'},
#  '22 - Red River - LA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 64,
#    'Yang': 0},
#   'County': 'Red River',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 8113.5, 'Yang': 0.0},
#   'State': 'LA',
#   'State_ID': '22'},
#  '53 - Clallam - WA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 128,
#    'Yang': 2},
#   'County': 'Clallam',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 6300.28,
#    'Yang': 11.0},
#   'State': 'WA',
#   'State_ID': '53'},
#  '42 - None - PA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 568,
#    'Yang': 3},
#   'County': 'None',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 33660.08000000001,
#    'Yang': 60.0},
#   'State': 'PA',
#   'State_ID': '42'},
#  '34 - None - NJ': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 1014,
#    'Yang': 10},
#   'County': 'None',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 60690.76000000001,
#    'Yang': 3167.0},
#   'State': 'NJ',
#   'State_ID': '34'},
#  '01 - Jefferson - AL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 763,
#    'Yang': 11},
#   'County': 'Jefferson',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 48466.17000000003,
#    'Yang': 85.0},
#   'State': 'AL',
#   'State_ID': '01'},
#  '47 - McMinn - TN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 8,
#    'Yang': 0},
#   'County': 'McMinn',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 375.0, 'Yang': 0.0},
#   'State': 'TN',
#   'State_ID': '47'},
#  '05 - Saline - AR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 159,
#    'Yang': 0},
#   'County': 'Saline',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 6537.439999999999,
#    'Yang': 0.0},
#   'State': 'AR',
#   'State_ID': '05'},
#  '36 - Westchester - NY': {'Count': {'Castro': 0,
#    'Delaney': 8,
#    'Trump': 1094,
#    'Yang': 31},
#   'County': 'Westchester',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 19900.0,
#    'Trump': 133800.13999999996,
#    'Yang': 17134.0},
#   'State': 'NY',
#   'State_ID': '36'},
#  '22 - Jefferson - LA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 617,
#    'Yang': 0},
#   'County': 'Jefferson',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 35264.84,
#    'Yang': 0.0},
#   'State': 'LA',
#   'State_ID': '22'},
#  '41 - Jackson - OR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 161,
#    'Yang': 14},
#   'County': 'Jackson',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 9724.749999999998,
#    'Yang': 37.0},
#   'State': 'OR',
#   'State_ID': '41'},
#  '47 - Hardin - TN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 29,
#    'Yang': 0},
#   'County': 'Hardin',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2322.59,
#    'Yang': 0.0},
#   'State': 'TN',
#   'State_ID': '47'},
#  '40 - Rogers - OK': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 150,
#    'Yang': 0},
#   'County': 'Rogers',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 15664.44,
#    'Yang': 0.0},
#   'State': 'OK',
#   'State_ID': '40'},
#  '28 - Tippah - MS': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 48,
#    'Yang': 0},
#   'County': 'Tippah',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 2125.0, 'Yang': 0.0},
#   'State': 'MS',
#   'State_ID': '28'},
#  '24 - Wicomico - MD': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 149,
#    'Yang': 0},
#   'County': 'Wicomico',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 18451.14,
#    'Yang': 0.0},
#   'State': 'MD',
#   'State_ID': '24'},
#  '22 - Calcasieu - LA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 189,
#    'Yang': 0},
#   'County': 'Calcasieu',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 13926.010000000002,
#    'Yang': 0.0},
#   'State': 'LA',
#   'State_ID': '22'},
#  '48 - None - TX': {'Count': {'Castro': 2,
#    'Delaney': 0,
#    'Trump': 1170,
#    'Yang': 1},
#   'County': 'None',
#   'Fundraising': {'Castro': 5400.0,
#    'Delaney': 0.0,
#    'Trump': 81282.88000000005,
#    'Yang': 500.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '34 - Union - NJ': {'Count': {'Castro': 0,
#    'Delaney': 3,
#    'Trump': 337,
#    'Yang': 5},
#   'County': 'Union',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 5400.0,
#    'Trump': 22437.840000000004,
#    'Yang': 760.0},
#   'State': 'NJ',
#   'State_ID': '34'},
#  '36 - Steuben - NY': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 51,
#    'Yang': 0},
#   'County': 'Steuben',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2766.25,
#    'Yang': 0.0},
#   'State': 'NY',
#   'State_ID': '36'},
#  '48 - Gray - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 10,
#    'Yang': 0},
#   'County': 'Gray',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 500.0, 'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '47 - Shelby - TN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 731,
#    'Yang': 2},
#   'County': 'Shelby',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 58322.999999999985,
#    'Yang': 2.0},
#   'State': 'TN',
#   'State_ID': '47'},
#  '06 - Tulare - CA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 591,
#    'Yang': 1},
#   'County': 'Tulare',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 28427.16,
#    'Yang': 10.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '42 - Bucks - PA': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 683,
#    'Yang': 4},
#   'County': 'Bucks',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 500.0,
#    'Trump': 37157.42999999999,
#    'Yang': 111.0},
#   'State': 'PA',
#   'State_ID': '42'},
#  '22 - Orleans - LA': {'Count': {'Castro': 1,
#    'Delaney': 0,
#    'Trump': 289,
#    'Yang': 15},
#   'County': 'Orleans',
#   'Fundraising': {'Castro': 2700.0,
#    'Delaney': 0.0,
#    'Trump': 43966.24999999999,
#    'Yang': 7319.0},
#   'State': 'LA',
#   'State_ID': '22'},
#  '06 - San Bernardino - CA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 1918,
#    'Yang': 5},
#   'County': 'San Bernardino',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 128214.56999999995,
#    'Yang': 45.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '37 - Onslow - NC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 104,
#    'Yang': 0},
#   'County': 'Onslow',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 11280.77,
#    'Yang': 0.0},
#   'State': 'NC',
#   'State_ID': '37'},
#  '06 - Alameda - CA': {'Count': {'Castro': 2,
#    'Delaney': 6,
#    'Trump': 1118,
#    'Yang': 82},
#   'County': 'Alameda',
#   'Fundraising': {'Castro': 3200.0,
#    'Delaney': 7800.0,
#    'Trump': 67250.63000000002,
#    'Yang': 12984.630000000001},
#   'State': 'CA',
#   'State_ID': '06'},
#  '29 - Buchanan - MO': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 57,
#    'Yang': 2},
#   'County': 'Buchanan',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2742.25,
#    'Yang': 15.0},
#   'State': 'MO',
#   'State_ID': '29'},
#  '42 - Chester - PA': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 656,
#    'Yang': 6},
#   'County': 'Chester',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 2700.0,
#    'Trump': 40860.40999999999,
#    'Yang': 641.89},
#   'State': 'PA',
#   'State_ID': '42'},
#  '06 - Santa Barbara - CA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 407,
#    'Yang': 14},
#   'County': 'Santa Barbara',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 32025.85,
#    'Yang': 222.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '06 - Los Angeles - CA': {'Count': {'Castro': 0,
#    'Delaney': 22,
#    'Trump': 8538,
#    'Yang': 164},
#   'County': 'Los Angeles',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 31800.0,
#    'Trump': 745324.4300000005,
#    'Yang': 11868.830000000002},
#   'State': 'CA',
#   'State_ID': '06'},
#  '18 - Posey - IN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 17,
#    'Yang': 0},
#   'County': 'Posey',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 4194.75,
#    'Yang': 0.0},
#   'State': 'IN',
#   'State_ID': '18'},
#  '12 - Hillsborough - FL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 1511,
#    'Yang': 15},
#   'County': 'Hillsborough',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 115962.42999999996,
#    'Yang': 477.0},
#   'State': 'FL',
#   'State_ID': '12'},
#  '12 - Indian River - FL': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 414,
#    'Yang': 1},
#   'County': 'Indian River',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 1000.0,
#    'Trump': 63744.890000000014,
#    'Yang': 20.0},
#   'State': 'FL',
#   'State_ID': '12'},
#  '29 - Miller - MO': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 73,
#    'Yang': 0},
#   'County': 'Miller',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 5339.249999999999,
#    'Yang': 0.0},
#   'State': 'MO',
#   'State_ID': '29'},
#  '12 - Palm Beach - FL': {'Count': {'Castro': 0,
#    'Delaney': 3,
#    'Trump': 2798,
#    'Yang': 15},
#   'County': 'Palm Beach',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 5400.0,
#    'Trump': 506326.7299999999,
#    'Yang': 1897.0},
#   'State': 'FL',
#   'State_ID': '12'},
#  '26 - None - MI': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 987,
#    'Yang': 11},
#   'County': 'None',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 500.0,
#    'Trump': 56877.619999999995,
#    'Yang': 1292.0},
#   'State': 'MI',
#   'State_ID': '26'},
#  '06 - Ventura - CA': {'Count': {'Castro': 0,
#    'Delaney': 8,
#    'Trump': 1291,
#    'Yang': 13},
#   'County': 'Ventura',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 9900.0,
#    'Trump': 97282.60000000006,
#    'Yang': 143.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '48 - Jack - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 22,
#    'Yang': 0},
#   'County': 'Jack',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 796.49, 'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '48 - Travis - TX': {'Count': {'Castro': 12,
#    'Delaney': 0,
#    'Trump': 1957,
#    'Yang': 22},
#   'County': 'Travis',
#   'Fundraising': {'Castro': 25550.0,
#    'Delaney': 0.0,
#    'Trump': 184193.50000000006,
#    'Yang': 1210.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '26 - Wayne - MI': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 904,
#    'Yang': 8},
#   'County': 'Wayne',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 2000.0,
#    'Trump': 72503.67000000001,
#    'Yang': 158.0},
#   'State': 'MI',
#   'State_ID': '26'},
#  '37 - Gaston - NC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 95,
#    'Yang': 0},
#   'County': 'Gaston',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 8948.619999999999,
#    'Yang': 0.0},
#   'State': 'NC',
#   'State_ID': '37'},
#  '42 - Westmoreland - PA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 264,
#    'Yang': 0},
#   'County': 'Westmoreland',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 16576.52,
#    'Yang': 0.0},
#   'State': 'PA',
#   'State_ID': '42'},
#  '27 - Swift - MN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 5,
#    'Yang': 0},
#   'County': 'Swift',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 249.99999999999994,
#    'Yang': 0.0},
#   'State': 'MN',
#   'State_ID': '27'},
#  '33 - None - NH': {'Count': {'Castro': 0,
#    'Delaney': 2,
#    'Trump': 587,
#    'Yang': 10},
#   'County': 'None',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 2000.0,
#    'Trump': 46276.639999999985,
#    'Yang': 73.0},
#   'State': 'NH',
#   'State_ID': '33'},
#  '27 - Winona - MN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 25,
#    'Yang': 0},
#   'County': 'Winona',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 1047.5, 'Yang': 0.0},
#   'State': 'MN',
#   'State_ID': '27'},
#  '51 - Virginia Beach (city) - VA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 523,
#    'Yang': 5},
#   'County': 'Virginia Beach (city)',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 32038.29,
#    'Yang': 28.0},
#   'State': 'VA',
#   'State_ID': '51'},
#  '34 - Sussex - NJ': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 214,
#    'Yang': 1},
#   'County': 'Sussex',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 7563.250000000002,
#    'Yang': 250.0},
#   'State': 'NJ',
#   'State_ID': '34'},
#  '05 - Van Buren - AR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 28,
#    'Yang': 0},
#   'County': 'Van Buren',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 1221.25,
#    'Yang': 0.0},
#   'State': 'AR',
#   'State_ID': '05'},
#  '16 - Idaho - ID': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 24,
#    'Yang': 0},
#   'County': 'Idaho',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 1333.1, 'Yang': 0.0},
#   'State': 'ID',
#   'State_ID': '16'},
#  '53 - Pierce - WA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 804,
#    'Yang': 7},
#   'County': 'Pierce',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 40874.44000000002,
#    'Yang': 102.0},
#   'State': 'WA',
#   'State_ID': '53'},
#  '12 - Orange - FL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 1682,
#    'Yang': 19},
#   'County': 'Orange',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 157958.39,
#    'Yang': 2167.0},
#   'State': 'FL',
#   'State_ID': '12'},
#  '42 - Washington - PA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 233,
#    'Yang': 0},
#   'County': 'Washington',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 16587.44,
#    'Yang': 0.0},
#   'State': 'PA',
#   'State_ID': '42'},
#  '39 - Pickaway - OH': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 23,
#    'Yang': 0},
#   'County': 'Pickaway',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 1895.0, 'Yang': 0.0},
#   'State': 'OH',
#   'State_ID': '39'},
#  '06 - Sacramento - CA': {'Count': {'Castro': 0,
#    'Delaney': 3,
#    'Trump': 1325,
#    'Yang': 15},
#   'County': 'Sacramento',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 75.0,
#    'Trump': 91578.78000000001,
#    'Yang': 107.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '55 - Dane - WI': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 314,
#    'Yang': 14},
#   'County': 'Dane',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 500.0,
#    'Trump': 23428.239999999998,
#    'Yang': 193.0},
#   'State': 'WI',
#   'State_ID': '55'},
#  '40 - Creek - OK': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 53,
#    'Yang': 0},
#   'County': 'Creek',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 3770.66,
#    'Yang': 0.0},
#   'State': 'OK',
#   'State_ID': '40'},
#  '18 - Hamilton - IN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 492,
#    'Yang': 5},
#   'County': 'Hamilton',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 27173.989999999994,
#    'Yang': 85.0},
#   'State': 'IN',
#   'State_ID': '18'},
#  '21 - Scott - KY': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 69,
#    'Yang': 0},
#   'County': 'Scott',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 2695.0, 'Yang': 0.0},
#   'State': 'KY',
#   'State_ID': '21'},
#  '19 - Buena Vista - IA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 18,
#    'Yang': 0},
#   'County': 'Buena Vista',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 3156.25,
#    'Yang': 0.0},
#   'State': 'IA',
#   'State_ID': '19'},
#  '06 - Sutter - CA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 102,
#    'Yang': 0},
#   'County': 'Sutter',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 5043.5, 'Yang': 0.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '30 - None - MT': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 26,
#    'Yang': 0},
#   'County': 'None',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2557.4100000000003,
#    'Yang': 0.0},
#   'State': 'MT',
#   'State_ID': '30'},
#  '48 - Bastrop - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 67,
#    'Yang': 3},
#   'County': 'Bastrop',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 6462.75,
#    'Yang': 40.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '21 - Graves - KY': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 49,
#    'Yang': 0},
#   'County': 'Graves',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2903.33,
#    'Yang': 0.0},
#   'State': 'KY',
#   'State_ID': '21'},
#  '29 - St. Louis - MO': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 1077,
#    'Yang': 9},
#   'County': 'St. Louis',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 2500.0,
#    'Trump': 56944.77,
#    'Yang': 400.0},
#   'State': 'MO',
#   'State_ID': '29'},
#  '48 - Lamar - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 34,
#    'Yang': 0},
#   'County': 'Lamar',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 3062.5, 'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '54 - Mercer - WV': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 9,
#    'Yang': 0},
#   'County': 'Mercer',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 327.5, 'Yang': 0.0},
#   'State': 'WV',
#   'State_ID': '54'},
#  '13 - Fulton - GA': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 1829,
#    'Yang': 23},
#   'County': 'Fulton',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 500.0,
#    'Trump': 123354.79000000002,
#    'Yang': 2387.0},
#   'State': 'GA',
#   'State_ID': '13'},
#  '53 - Skagit - WA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 179,
#    'Yang': 2},
#   'County': 'Skagit',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 11883.75,
#    'Yang': 21.0},
#   'State': 'WA',
#   'State_ID': '53'},
#  '41 - Jefferson - OR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 4,
#    'Yang': 0},
#   'County': 'Jefferson',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 70.0, 'Yang': 0.0},
#   'State': 'OR',
#   'State_ID': '41'},
#  '45 - Greenville - SC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 574,
#    'Yang': 1},
#   'County': 'Greenville',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 49715.69,
#    'Yang': 1.0},
#   'State': 'SC',
#   'State_ID': '45'},
#  '08 - Fremont - CO': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 96,
#    'Yang': 0},
#   'County': 'Fremont',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 3649.06,
#    'Yang': 0.0},
#   'State': 'CO',
#   'State_ID': '08'},
#  '41 - Multnomah - OR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 707,
#    'Yang': 61},
#   'County': 'Multnomah',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 30746.049999999992,
#    'Yang': 2304.0},
#   'State': 'OR',
#   'State_ID': '41'},
#  '06 - Orange - CA': {'Count': {'Castro': 1,
#    'Delaney': 2,
#    'Trump': 6101,
#    'Yang': 39},
#   'County': 'Orange',
#   'Fundraising': {'Castro': 2700.0,
#    'Delaney': 1500.0,
#    'Trump': 392042.95999999956,
#    'Yang': 4109.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '22 - Assumption - LA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 3,
#    'Yang': 0},
#   'County': 'Assumption',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 250.0, 'Yang': 0.0},
#   'State': 'LA',
#   'State_ID': '22'},
#  '56 - Natrona - WY': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 103,
#    'Yang': 0},
#   'County': 'Natrona',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 5684.04,
#    'Yang': 0.0},
#   'State': 'WY',
#   'State_ID': '56'},
#  '36 - New York - NY': {'Count': {'Castro': 1,
#    'Delaney': 22,
#    'Trump': 2501,
#    'Yang': 249},
#   'County': 'New York',
#   'Fundraising': {'Castro': 1000.0,
#    'Delaney': 33550.0,
#    'Trump': 531226.9099999999,
#    'Yang': 143968.13},
#   'State': 'NY',
#   'State_ID': '36'},
#  '45 - York - SC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 238,
#    'Yang': 0},
#   'County': 'York',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 18436.09,
#    'Yang': 0.0},
#   'State': 'SC',
#   'State_ID': '45'},
#  '47 - Wilson - TN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 187,
#    'Yang': 0},
#   'County': 'Wilson',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 13568.57,
#    'Yang': 0.0},
#   'State': 'TN',
#   'State_ID': '47'},
#  '25 - Essex - MA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 556,
#    'Yang': 12},
#   'County': 'Essex',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 36203.229999999996,
#    'Yang': 357.0},
#   'State': 'MA',
#   'State_ID': '25'},
#  '51 - Fairfax - VA': {'Count': {'Castro': 0,
#    'Delaney': 46,
#    'Trump': 2183,
#    'Yang': 32},
#   'County': 'Fairfax',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 52706.799999999974,
#    'Trump': 142405.25,
#    'Yang': 4292.0},
#   'State': 'VA',
#   'State_ID': '51'},
#  '47 - Knox - TN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 414,
#    'Yang': 9},
#   'County': 'Knox',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 21208.870000000006,
#    'Yang': 1052.0},
#   'State': 'TN',
#   'State_ID': '47'},
#  '48 - Bell - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 232,
#    'Yang': 0},
#   'County': 'Bell',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 19974.84,
#    'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '12 - Broward - FL': {'Count': {'Castro': 0,
#    'Delaney': 2,
#    'Trump': 2707,
#    'Yang': 5},
#   'County': 'Broward',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 5400.0,
#    'Trump': 269815.6,
#    'Yang': 91.0},
#   'State': 'FL',
#   'State_ID': '12'},
#  '47 - Roane - TN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 65,
#    'Yang': 0},
#   'County': 'Roane',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 4112.5, 'Yang': 0.0},
#   'State': 'TN',
#   'State_ID': '47'},
#  '04 - Pinal - AZ': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 281,
#    'Yang': 0},
#   'County': 'Pinal',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 11846.26,
#    'Yang': 0.0},
#   'State': 'AZ',
#   'State_ID': '04'},
#  '04 - Yuma - AZ': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 217,
#    'Yang': 2},
#   'County': 'Yuma',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 8336.2,
#    'Yang': 30.0},
#   'State': 'AZ',
#   'State_ID': '04'},
#  '12 - Lee - FL': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 1363,
#    'Yang': 0},
#   'County': 'Lee',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 500.0,
#    'Trump': 105448.21,
#    'Yang': 0.0},
#   'State': 'FL',
#   'State_ID': '12'},
#  '36 - Suffolk - NY': {'Count': {'Castro': 0,
#    'Delaney': 2,
#    'Trump': 2849,
#    'Yang': 8},
#   'County': 'Suffolk',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 2000.0,
#    'Trump': 177628.47999999995,
#    'Yang': 2688.0},
#   'State': 'NY',
#   'State_ID': '36'},
#  '48 - Collin - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 1615,
#    'Yang': 4},
#   'County': 'Collin',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 161893.87000000005,
#    'Yang': 42.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '29 - Jackson - MO': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 872,
#    'Yang': 10},
#   'County': 'Jackson',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 35671.69,
#    'Yang': 255.0},
#   'State': 'MO',
#   'State_ID': '29'},
#  '36 - Nassau - NY': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 1880,
#    'Yang': 19},
#   'County': 'Nassau',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 2700.0,
#    'Trump': 189304.28,
#    'Yang': 9076.0},
#   'State': 'NY',
#   'State_ID': '36'},
#  '24 - Howard - MD': {'Count': {'Castro': 0,
#    'Delaney': 3,
#    'Trump': 215,
#    'Yang': 0},
#   'County': 'Howard',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 1750.0,
#    'Trump': 17203.730000000003,
#    'Yang': 0.0},
#   'State': 'MD',
#   'State_ID': '24'},
#  '17 - Cook - IL': {'Count': {'Castro': 0,
#    'Delaney': 28,
#    'Trump': 2715,
#    'Yang': 78},
#   'County': 'Cook',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 29301.000000000004,
#    'Trump': 161046.21000000008,
#    'Yang': 1097.2},
#   'State': 'IL',
#   'State_ID': '17'},
#  '29 - Boone - MO': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 196,
#    'Yang': 7},
#   'County': 'Boone',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 500.0,
#    'Trump': 12806.570000000002,
#    'Yang': 73.0},
#   'State': 'MO',
#   'State_ID': '29'},
#  '06 - San Joaquin - CA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 880,
#    'Yang': 0},
#   'County': 'San Joaquin',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 39557.7,
#    'Yang': 0.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '06 - San Benito - CA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 82,
#    'Yang': 0},
#   'County': 'San Benito',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2290.96,
#    'Yang': 0.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '41 - Clackamas - OR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 459,
#    'Yang': 4},
#   'County': 'Clackamas',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 28132.730000000003,
#    'Yang': 15.99},
#   'State': 'OR',
#   'State_ID': '41'},
#  '31 - Pierce - NE': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 9,
#    'Yang': 0},
#   'County': 'Pierce',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 350.0, 'Yang': 0.0},
#   'State': 'NE',
#   'State_ID': '31'},
#  '48 - El Paso - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 456,
#    'Yang': 1},
#   'County': 'El Paso',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 31666.76,
#    'Yang': 20.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '13 - Tift - GA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 30,
#    'Yang': 0},
#   'County': 'Tift',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 1385.0, 'Yang': 0.0},
#   'State': 'GA',
#   'State_ID': '13'},
#  '26 - Cass - MI': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 22,
#    'Yang': 0},
#   'County': 'Cass',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 1330.0, 'Yang': 0.0},
#   'State': 'MI',
#   'State_ID': '26'},
#  '13 - Gwinnett - GA': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 524,
#    'Yang': 0},
#   'County': 'Gwinnett',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 1000.0,
#    'Trump': 29700.400000000005,
#    'Yang': 0.0},
#   'State': 'GA',
#   'State_ID': '13'},
#  '12 - Collier - FL': {'Count': {'Castro': 0,
#    'Delaney': 3,
#    'Trump': 1164,
#    'Yang': 0},
#   'County': 'Collier',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 8100.0,
#    'Trump': 132321.27000000002,
#    'Yang': 0.0},
#   'State': 'FL',
#   'State_ID': '12'},
#  '39 - Mercer - OH': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 25,
#    'Yang': 0},
#   'County': 'Mercer',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 1308.75,
#    'Yang': 0.0},
#   'State': 'OH',
#   'State_ID': '39'},
#  '41 - Lane - OR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 253,
#    'Yang': 11},
#   'County': 'Lane',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 13172.140000000001,
#    'Yang': 49.0},
#   'State': 'OR',
#   'State_ID': '41'},
#  '53 - Klickitat - WA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 31,
#    'Yang': 0},
#   'County': 'Klickitat',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 970.0000000000001,
#    'Yang': 0.0},
#   'State': 'WA',
#   'State_ID': '53'},
#  '06 - Stanislaus - CA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 485,
#    'Yang': 2},
#   'County': 'Stanislaus',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 35694.869999999995,
#    'Yang': 10.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '09 - Hartford - CT': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 673,
#    'Yang': 2},
#   'County': 'Hartford',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 37767.23999999999,
#    'Yang': 2.0},
#   'State': 'CT',
#   'State_ID': '09'},
#  '30 - Yellowstone - MT': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 208,
#    'Yang': 3},
#   'County': 'Yellowstone',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 15691.93,
#    'Yang': 11.39},
#   'State': 'MT',
#   'State_ID': '30'},
#  '13 - Richmond - GA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 189,
#    'Yang': 0},
#   'County': 'Richmond',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 14171.019999999999,
#    'Yang': 0.0},
#   'State': 'GA',
#   'State_ID': '13'},
#  '48 - Johnson - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 110,
#    'Yang': 0},
#   'County': 'Johnson',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 9799.380000000001,
#    'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '39 - Montgomery - OH': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 488,
#    'Yang': 1},
#   'County': 'Montgomery',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 33769.94,
#    'Yang': 10.0},
#   'State': 'OH',
#   'State_ID': '39'},
#  '21 - Jefferson - KY': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 692,
#    'Yang': 4},
#   'County': 'Jefferson',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 2700.0,
#    'Trump': 40538.850000000006,
#    'Yang': 42.0},
#   'State': 'KY',
#   'State_ID': '21'},
#  '32 - Clark - NV': {'Count': {'Castro': 0,
#    'Delaney': 2,
#    'Trump': 2763,
#    'Yang': 28},
#   'County': 'Clark',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 2500.0,
#    'Trump': 195205.75000000006,
#    'Yang': 1836.0},
#   'State': 'NV',
#   'State_ID': '32'},
#  '24 - Charles - MD': {'Count': {'Castro': 0,
#    'Delaney': 10,
#    'Trump': 196,
#    'Yang': 2},
#   'County': 'Charles',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 725.0,
#    'Trump': 7933.62,
#    'Yang': 2.0},
#   'State': 'MD',
#   'State_ID': '24'},
#  '37 - Lee - NC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 63,
#    'Yang': 0},
#   'County': 'Lee',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 2278.9, 'Yang': 0.0},
#   'State': 'NC',
#   'State_ID': '37'},
#  '06 - San Luis Obispo - CA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 691,
#    'Yang': 18},
#   'County': 'San Luis Obispo',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 41680.170000000006,
#    'Yang': 265.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '10 - Sussex - DE': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 219,
#    'Yang': 0},
#   'County': 'Sussex',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 16972.39,
#    'Yang': 0.0},
#   'State': 'DE',
#   'State_ID': '10'},
#  '53 - Kitsap - WA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 281,
#    'Yang': 4},
#   'County': 'Kitsap',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 17763.129999999997,
#    'Yang': 554.0},
#   'State': 'WA',
#   'State_ID': '53'},
#  '41 - Josephine - OR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 99,
#    'Yang': 1},
#   'County': 'Josephine',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 7624.87,
#    'Yang': 1.0},
#   'State': 'OR',
#   'State_ID': '41'},
#  '47 - Morgan - TN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 20,
#    'Yang': 0},
#   'County': 'Morgan',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 1030.0, 'Yang': 0.0},
#   'State': 'TN',
#   'State_ID': '47'},
#  '12 - Santa Rosa - FL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 235,
#    'Yang': 0},
#   'County': 'Santa Rosa',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 10651.120000000003,
#    'Yang': 0.0},
#   'State': 'FL',
#   'State_ID': '12'},
#  '27 - Otter Tail - MN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 28,
#    'Yang': 0},
#   'County': 'Otter Tail',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 1620.0, 'Yang': 0.0},
#   'State': 'MN',
#   'State_ID': '27'},
#  '37 - Buncombe - NC': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 317,
#    'Yang': 2},
#   'County': 'Buncombe',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 500.0,
#    'Trump': 27628.26,
#    'Yang': 30.0},
#   'State': 'NC',
#   'State_ID': '37'},
#  '32 - White Pine - NV': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 59,
#    'Yang': 0},
#   'County': 'White Pine',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 4960.77,
#    'Yang': 0.0},
#   'State': 'NV',
#   'State_ID': '32'},
#  '37 - Stanly - NC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 80,
#    'Yang': 0},
#   'County': 'Stanly',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 3871.76,
#    'Yang': 0.0},
#   'State': 'NC',
#   'State_ID': '37'},
#  '39 - Hamilton - OH': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 641,
#    'Yang': 7},
#   'County': 'Hamilton',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 44034.19,
#    'Yang': 341.0},
#   'State': 'OH',
#   'State_ID': '39'},
#  '17 - Will - IL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 399,
#    'Yang': 2},
#   'County': 'Will',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 20544.549999999996,
#    'Yang': 11.0},
#   'State': 'IL',
#   'State_ID': '17'},
#  '48 - Dallas - TX': {'Count': {'Castro': 3,
#    'Delaney': 1,
#    'Trump': 3437,
#    'Yang': 20},
#   'County': 'Dallas',
#   'Fundraising': {'Castro': 1000.0,
#    'Delaney': 500.0,
#    'Trump': 548012.8100000003,
#    'Yang': 429.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '13 - Banks - GA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 7,
#    'Yang': 0},
#   'County': 'Banks',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 535.0, 'Yang': 0.0},
#   'State': 'GA',
#   'State_ID': '13'},
#  '45 - Anderson - SC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 222,
#    'Yang': 0},
#   'County': 'Anderson',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 7309.84,
#    'Yang': 0.0},
#   'State': 'SC',
#   'State_ID': '45'},
#  '39 - Columbiana - OH': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 77,
#    'Yang': 0},
#   'County': 'Columbiana',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2551.71,
#    'Yang': 0.0},
#   'State': 'OH',
#   'State_ID': '39'},
#  '42 - Franklin - PA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 97,
#    'Yang': 1},
#   'County': 'Franklin',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 6495.719999999999,
#    'Yang': 5.0},
#   'State': 'PA',
#   'State_ID': '42'},
#  '32 - Carson City (city) - NV': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 149,
#    'Yang': 1},
#   'County': 'Carson City (city)',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 9498.43,
#    'Yang': 5.0},
#   'State': 'NV',
#   'State_ID': '32'},
#  '36 - Kings - NY': {'Count': {'Castro': 2,
#    'Delaney': 3,
#    'Trump': 1110,
#    'Yang': 122},
#   'County': 'Kings',
#   'Fundraising': {'Castro': 500.0,
#    'Delaney': 75.0,
#    'Trump': 80117.75,
#    'Yang': 20768.0},
#   'State': 'NY',
#   'State_ID': '36'},
#  '36 - Orange - NY': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 275,
#    'Yang': 1},
#   'County': 'Orange',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 17476.73,
#    'Yang': 10.0},
#   'State': 'NY',
#   'State_ID': '36'},
#  '36 - Delaware - NY': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 17,
#    'Yang': 0},
#   'County': 'Delaware',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2471.25,
#    'Yang': 0.0},
#   'State': 'NY',
#   'State_ID': '36'},
#  '48 - Wise - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 95,
#    'Yang': 3},
#   'County': 'Wise',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 4796.86,
#    'Yang': 16.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '25 - None - MA': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 1192,
#    'Yang': 11},
#   'County': 'None',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 500.0,
#    'Trump': 57696.07000000001,
#    'Yang': 111.0},
#   'State': 'MA',
#   'State_ID': '25'},
#  '39 - Summit - OH': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 614,
#    'Yang': 4},
#   'County': 'Summit',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 45342.329999999994,
#    'Yang': 12.0},
#   'State': 'OH',
#   'State_ID': '39'},
#  '18 - Jasper - IN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 12,
#    'Yang': 0},
#   'County': 'Jasper',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 427.5, 'Yang': 0.0},
#   'State': 'IN',
#   'State_ID': '18'},
#  '18 - Marion - IN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 678,
#    'Yang': 5},
#   'County': 'Marion',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 52541.69000000001,
#    'Yang': 14.0},
#   'State': 'IN',
#   'State_ID': '18'},
#  '51 - Loudoun - VA': {'Count': {'Castro': 0,
#    'Delaney': 2,
#    'Trump': 709,
#    'Yang': 2},
#   'County': 'Loudoun',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 1000.0,
#    'Trump': 36934.499999999985,
#    'Yang': 70.0},
#   'State': 'VA',
#   'State_ID': '51'},
#  '41 - Marion - OR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 192,
#    'Yang': 7},
#   'County': 'Marion',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 11082.43,
#    'Yang': 89.0},
#   'State': 'OR',
#   'State_ID': '41'},
#  '53 - Thurston - WA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 341,
#    'Yang': 4},
#   'County': 'Thurston',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 22527.54,
#    'Yang': 1011.0},
#   'State': 'WA',
#   'State_ID': '53'},
#  '53 - Clark - WA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 622,
#    'Yang': 8},
#   'County': 'Clark',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 30369.320000000003,
#    'Yang': 77.0},
#   'State': 'WA',
#   'State_ID': '53'},
#  '06 - Lake - CA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 114,
#    'Yang': 0},
#   'County': 'Lake',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 5900.7, 'Yang': 0.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '01 - Conecuh - AL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 60,
#    'Yang': 0},
#   'County': 'Conecuh',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 2667.5, 'Yang': 0.0},
#   'State': 'AL',
#   'State_ID': '01'},
#  '13 - Henry - GA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 149,
#    'Yang': 1},
#   'County': 'Henry',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 8011.42,
#    'Yang': 1.0},
#   'State': 'GA',
#   'State_ID': '13'},
#  '06 - Napa - CA': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 237,
#    'Yang': 1},
#   'County': 'Napa',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 2700.0,
#    'Trump': 10501.84,
#    'Yang': 20.0},
#   'State': 'CA',
#   'State_ID': '06'},
#  '39 - Butler - OH': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 469,
#    'Yang': 0},
#   'County': 'Butler',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 33890.59,
#    'Yang': 0.0},
#   'State': 'OH',
#   'State_ID': '39'},
#  '48 - Galveston - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 522,
#    'Yang': 1},
#   'County': 'Galveston',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 34249.549999999996,
#    'Yang': 10.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '51 - None - VA': {'Count': {'Castro': 0,
#    'Delaney': 4,
#    'Trump': 824,
#    'Yang': 4},
#   'County': 'None',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 6900.0,
#    'Trump': 47220.189999999995,
#    'Yang': 10.0},
#   'State': 'VA',
#   'State_ID': '51'},
#  '13 - Toombs - GA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 13,
#    'Yang': 0},
#   'County': 'Toombs',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 775.0, 'Yang': 0.0},
#   'State': 'GA',
#   'State_ID': '13'},
#  '51 - Pulaski - VA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 12,
#    'Yang': 0},
#   'County': 'Pulaski',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 989.21, 'Yang': 0.0},
#   'State': 'VA',
#   'State_ID': '51'},
#  '39 - Erie - OH': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 68,
#    'Yang': 0},
#   'County': 'Erie',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 4001.4399999999996,
#    'Yang': 0.0},
#   'State': 'OH',
#   'State_ID': '39'},
#  '04 - Cochise - AZ': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 131,
#    'Yang': 0},
#   'County': 'Cochise',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 5133.3, 'Yang': 0.0},
#   'State': 'AZ',
#   'State_ID': '04'},
#  '20 - Harvey - KS': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 16,
#    'Yang': 0},
#   'County': 'Harvey',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 363.75, 'Yang': 0.0},
#   'State': 'KS',
#   'State_ID': '20'},
#  '37 - Union - NC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 262,
#    'Yang': 2},
#   'County': 'Union',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 34608.25,
#    'Yang': 11.0},
#   'State': 'NC',
#   'State_ID': '37'},
#  '51 - Augusta - VA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 91,
#    'Yang': 1},
#   'County': 'Augusta',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 7700.83,
#    'Yang': 250.0},
#   'State': 'VA',
#   'State_ID': '51'},
#  '23 - Lincoln - ME': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 20,
#    'Yang': 1},
#   'County': 'Lincoln',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 1112.5, 'Yang': 1.0},
#   'State': 'ME',
#   'State_ID': '23'},
#  '21 - Calloway - KY': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 39,
#    'Yang': 0},
#   'County': 'Calloway',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 1932.5, 'Yang': 0.0},
#   'State': 'KY',
#   'State_ID': '21'},
#  '08 - Gunnison - CO': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 13,
#    'Yang': 0},
#   'County': 'Gunnison',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 800.0, 'Yang': 0.0},
#   'State': 'CO',
#   'State_ID': '08'},
#  '18 - None - IN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 69,
#    'Yang': 1},
#   'County': 'None',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2006.9099999999999,
#    'Yang': 1.0},
#   'State': 'IN',
#   'State_ID': '18'},
#  '36 - Rensselaer - NY': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 129,
#    'Yang': 1},
#   'County': 'Rensselaer',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 5191.250000000001,
#    'Yang': 1.0},
#   'State': 'NY',
#   'State_ID': '36'},
#  '12 - None - FL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 1440,
#    'Yang': 7},
#   'County': 'None',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 136890.25,
#    'Yang': 28.0},
#   'State': 'FL',
#   'State_ID': '12'},
#  '48 - Ector - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 276,
#    'Yang': 0},
#   'County': 'Ector',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 47888.51,
#    'Yang': 0.0},
# ...
#   'State': 'GA',
#   'State_ID': '13'},
#  '22 - Washington - LA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 23,
#    'Yang': 0},
#   'County': 'Washington',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 875.0, 'Yang': 0.0},
#   'State': 'LA',
#   'State_ID': '22'},
#  '01 - Lee - AL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 117,
#    'Yang': 6},
#   'County': 'Lee',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 6002.25,
#    'Yang': 33.0},
#   'State': 'AL',
#   'State_ID': '01'},
#  '37 - Carteret - NC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 93,
#    'Yang': 0},
#   'County': 'Carteret',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 10277.390000000001,
#    'Yang': 0.0},
#   'State': 'NC',
#   'State_ID': '37'},
#  '48 - Hays - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 301,
#    'Yang': 0},
#   'County': 'Hays',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 21903.119999999995,
#    'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '48 - Matagorda - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 47,
#    'Yang': 0},
#   'County': 'Matagorda',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 2805.0, 'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '22 - Rapides - LA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 77,
#    'Yang': 0},
#   'County': 'Rapides',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2357.2599999999993,
#    'Yang': 0.0},
#   'State': 'LA',
#   'State_ID': '22'},
#  '19 - Jefferson - IA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 11,
#    'Yang': 1},
#   'County': 'Jefferson',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 888.75, 'Yang': 5.0},
#   'State': 'IA',
#   'State_ID': '19'},
#  '17 - Jefferson - IL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 53,
#    'Yang': 0},
#   'County': 'Jefferson',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 1474.75,
#    'Yang': 0.0},
#   'State': 'IL',
#   'State_ID': '17'},
#  '37 - Wilkes - NC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 56,
#    'Yang': 0},
#   'County': 'Wilkes',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2512.05,
#    'Yang': 0.0},
#   'State': 'NC',
#   'State_ID': '37'},
#  '54 - Berkeley - WV': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 45,
#    'Yang': 0},
#   'County': 'Berkeley',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 3887.4999999999995,
#    'Yang': 0.0},
#   'State': 'WV',
#   'State_ID': '54'},
#  '04 - Mohave - AZ': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 324,
#    'Yang': 0},
#   'County': 'Mohave',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 15040.330000000002,
#    'Yang': 0.0},
#   'State': 'AZ',
#   'State_ID': '04'},
#  '19 - Muscatine - IA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 12,
#    'Yang': 0},
#   'County': 'Muscatine',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 857.5, 'Yang': 0.0},
#   'State': 'IA',
#   'State_ID': '19'},
#  '48 - Madison - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 32,
#    'Yang': 0},
#   'County': 'Madison',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 3808.75,
#    'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '13 - Spalding - GA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 54,
#    'Yang': 0},
#   'County': 'Spalding',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 3616.25,
#    'Yang': 0.0},
#   'State': 'GA',
#   'State_ID': '13'},
#  '22 - Cameron - LA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 1,
#    'Yang': 0},
#   'County': 'Cameron',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 250.0, 'Yang': 0.0},
#   'State': 'LA',
#   'State_ID': '22'},
#  '21 - Madison - KY': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 35,
#    'Yang': 0},
#   'County': 'Madison',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2090.37,
#    'Yang': 0.0},
#   'State': 'KY',
#   'State_ID': '21'},
#  '48 - Van Zandt - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 69,
#    'Yang': 0},
#   'County': 'Van Zandt',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 2768.5, 'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '55 - Marathon - WI': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 162,
#    'Yang': 1},
#   'County': 'Marathon',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 15077.69,
#    'Yang': 20.0},
#   'State': 'WI',
#   'State_ID': '55'},
#  '28 - Covington - MS': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 9,
#    'Yang': 0},
#   'County': 'Covington',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 816.26, 'Yang': 0.0},
#   'State': 'MS',
#   'State_ID': '28'},
#  '37 - Hoke - NC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 36,
#    'Yang': 0},
#   'County': 'Hoke',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 1207.5, 'Yang': 0.0},
#   'State': 'NC',
#   'State_ID': '37'},
#  '24 - Worcester - MD': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 109,
#    'Yang': 0},
#   'County': 'Worcester',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 8632.5, 'Yang': 0.0},
#   'State': 'MD',
#   'State_ID': '24'},
#  '13 - Clarke - GA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 106,
#    'Yang': 0},
#   'County': 'Clarke',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 5564.859999999999,
#    'Yang': 0.0},
#   'State': 'GA',
#   'State_ID': '13'},
#  '37 - Catawba - NC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 129,
#    'Yang': 1},
#   'County': 'Catawba',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 4782.5,
#    'Yang': 100.0},
#   'State': 'NC',
#   'State_ID': '37'},
#  '04 - Gila - AZ': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 57,
#    'Yang': 0},
#   'County': 'Gila',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2338.25,
#    'Yang': 0.0},
#   'State': 'AZ',
#   'State_ID': '04'},
#  '51 - Dinwiddie - VA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 4,
#    'Yang': 0},
#   'County': 'Dinwiddie',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 125.0, 'Yang': 0.0},
#   'State': 'VA',
#   'State_ID': '51'},
#  '01 - Winston - AL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 147,
#    'Yang': 0},
#   'County': 'Winston',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 6928.75,
#    'Yang': 0.0},
#   'State': 'AL',
#   'State_ID': '01'},
#  '48 - Yoakum - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 10,
#    'Yang': 0},
#   'County': 'Yoakum',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 521.25, 'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '05 - Columbia - AR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 10,
#    'Yang': 0},
#   'County': 'Columbia',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 1500.0, 'Yang': 0.0},
#   'State': 'AR',
#   'State_ID': '05'},
#  '08 - Mesa - CO': {'Count': {'Castro': 0,
#    'Delaney': 1,
#    'Trump': 150,
#    'Yang': 0},
#   'County': 'Mesa',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 500.0,
#    'Trump': 10018.23,
#    'Yang': 0.0},
#   'State': 'CO',
#   'State_ID': '08'},
#  '39 - Defiance - OH': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 37,
#    'Yang': 0},
#   'County': 'Defiance',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 1321.87,
#    'Yang': 0.0},
#   'State': 'OH',
#   'State_ID': '39'},
#  '18 - Morgan - IN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 94,
#    'Yang': 1},
#   'County': 'Morgan',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 4745.75,
#    'Yang': 5.0},
#   'State': 'IN',
#   'State_ID': '18'},
#  '12 - Glades - FL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 13,
#    'Yang': 0},
#   'County': 'Glades',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 512.5, 'Yang': 0.0},
#   'State': 'FL',
#   'State_ID': '12'},
#  '27 - Ramsey - MN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 263,
#    'Yang': 7},
#   'County': 'Ramsey',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 14542.429999999998,
#    'Yang': 106.0},
#   'State': 'MN',
#   'State_ID': '27'},
#  '37 - Orange - NC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 160,
#    'Yang': 4},
#   'County': 'Orange',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 11575.549999999997,
#    'Yang': 571.0},
#   'State': 'NC',
#   'State_ID': '37'},
#  '39 - Portage - OH': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 66,
#    'Yang': 0},
#   'County': 'Portage',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 3402.6099999999997,
#    'Yang': 0.0},
#   'State': 'OH',
#   'State_ID': '39'},
#  '33 - Belknap - NH': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 43,
#    'Yang': 0},
#   'County': 'Belknap',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 1357.25,
#    'Yang': 0.0},
#   'State': 'NH',
#   'State_ID': '33'},
#  '20 - Crawford - KS': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 7,
#    'Yang': 0},
#   'County': 'Crawford',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 390.0, 'Yang': 0.0},
#   'State': 'KS',
#   'State_ID': '20'},
#  '55 - Lafayette - WI': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 3,
#    'Yang': 0},
#   'County': 'Lafayette',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 35.0, 'Yang': 0.0},
#   'State': 'WI',
#   'State_ID': '55'},
#  '48 - Anderson - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 38,
#    'Yang': 0},
#   'County': 'Anderson',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 2285.0, 'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '22 - Avoyelles - LA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 45,
#    'Yang': 1},
#   'County': 'Avoyelles',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2140.0,
#    'Yang': 10.0},
#   'State': 'LA',
#   'State_ID': '22'},
#  '20 - Miami - KS': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 19,
#    'Yang': 0},
#   'County': 'Miami',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2178.75,
#    'Yang': 0.0},
#   'State': 'KS',
#   'State_ID': '20'},
#  '26 - Tuscola - MI': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 37,
#    'Yang': 0},
#   'County': 'Tuscola',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 1058.74,
#    'Yang': 0.0},
#   'State': 'MI',
#   'State_ID': '26'},
#  '53 - Walla Walla - WA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 111,
#    'Yang': 1},
#   'County': 'Walla Walla',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 4198.5, 'Yang': 1.0},
#   'State': 'WA',
#   'State_ID': '53'},
#  '48 - Polk - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 80,
#    'Yang': 0},
#   'County': 'Polk',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 4039.9400000000005,
#    'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '48 - Hood - TX': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 104,
#    'Yang': 0},
#   'County': 'Hood',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 6588.999999999999,
#    'Yang': 0.0},
#   'State': 'TX',
#   'State_ID': '48'},
#  '41 - Klamath - OR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 111,
#    'Yang': 1},
#   'County': 'Klamath',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 7121.7699999999995,
#    'Yang': 1.0},
#   'State': 'OR',
#   'State_ID': '41'},
#  '42 - Lycoming - PA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 67,
#    'Yang': 0},
#   'County': 'Lycoming',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 14065.750000000004,
#    'Yang': 0.0},
#   'State': 'PA',
#   'State_ID': '42'},
#  '05 - Garland - AR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 163,
#    'Yang': 0},
#   'County': 'Garland',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 6433.4, 'Yang': 0.0},
#   'State': 'AR',
#   'State_ID': '05'},
#  '45 - Oconee - SC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 139,
#    'Yang': 1},
#   'County': 'Oconee',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 7274.870000000001,
#    'Yang': 10.0},
#   'State': 'SC',
#   'State_ID': '45'},
#  '36 - Oswego - NY': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 37,
#    'Yang': 0},
#   'County': 'Oswego',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 1993.5, 'Yang': 0.0},
#   'State': 'NY',
#   'State_ID': '36'},
#  '13 - Effingham - GA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 61,
#    'Yang': 0},
#   'County': 'Effingham',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2323.75,
#    'Yang': 0.0},
#   'State': 'GA',
#   'State_ID': '13'},
#  '21 - Grant - KY': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 37,
#    'Yang': 0},
#   'County': 'Grant',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 1833.75,
#    'Yang': 0.0},
#   'State': 'KY',
#   'State_ID': '21'},
#  '12 - Putnam - FL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 32,
#    'Yang': 0},
#   'County': 'Putnam',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 3801.0, 'Yang': 0.0},
#   'State': 'FL',
#   'State_ID': '12'},
#  '37 - Henderson - NC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 134,
#    'Yang': 0},
#   'County': 'Henderson',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 12863.3,
#    'Yang': 0.0},
#   'State': 'NC',
#   'State_ID': '37'},
#  '13 - Whitfield - GA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 58,
#    'Yang': 0},
#   'County': 'Whitfield',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 2655.0, 'Yang': 0.0},
#   'State': 'GA',
#   'State_ID': '13'},
#  '42 - Armstrong - PA': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 50,
#    'Yang': 0},
#   'County': 'Armstrong',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2766.25,
#    'Yang': 0.0},
#   'State': 'PA',
#   'State_ID': '42'},
#  '17 - Douglas - IL': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 16,
#    'Yang': 1},
#   'County': 'Douglas',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 1257.5,
#    'Yang': 20.0},
#   'State': 'IL',
#   'State_ID': '17'},
#  '18 - Delaware - IN': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 98,
#    'Yang': 5},
#   'County': 'Delaware',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2635.0899999999997,
#    'Yang': 5.0},
#   'State': 'IN',
#   'State_ID': '18'},
#  '41 - Hood River - OR': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 15,
#    'Yang': 0},
#   'County': 'Hood River',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 850.0, 'Yang': 0.0},
#   'State': 'OR',
#   'State_ID': '41'},
#  '45 - Georgetown - SC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 111,
#    'Yang': 0},
#   'County': 'Georgetown',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 5601.4400000000005,
#    'Yang': 0.0},
#   'State': 'SC',
#   'State_ID': '45'},
#  '16 - Canyon - ID': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 165,
#    'Yang': 0},
#   'County': 'Canyon',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 6156.009999999999,
#    'Yang': 0.0},
#   'State': 'ID',
#   'State_ID': '16'},
#  '28 - Jefferson Davis - MS': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 13,
#    'Yang': 0},
#   'County': 'Jefferson Davis',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 500.0, 'Yang': 0.0},
#   'State': 'MS',
#   'State_ID': '28'},
#  '37 - Rutherford - NC': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 90,
#    'Yang': 0},
#   'County': 'Rutherford',
#   'Fundraising': {'Castro': 0.0, 'Delaney': 0.0, 'Trump': 2934.1, 'Yang': 0.0},
#   'State': 'NC',
#   'State_ID': '37'},
#  '56 - Campbell - WY': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 48,
#    'Yang': 0},
#   'County': 'Campbell',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 2318.75,
#    'Yang': 0.0},
#   'State': 'WY',
#   'State_ID': '56'},
#  '38 - Cass - ND': {'Count': {'Castro': 0,
#    'Delaney': 0,
#    'Trump': 88,
#    'Yang': 0},
#   'County': 'Cass',
#   'Fundraising': {'Castro': 0.0,
#    'Delaney': 0.0,
#    'Trump': 12158.130000000001,
#    'Yang': 0.0},
#   'State': 'ND',
#   'State_ID': '38'},
#  ...}

# %%
with open('data/counties.geojson', 'r', encoding="ISO-8859-1") as f:
    county_geojson = json.load(f)

    
for i, geo_county in enumerate(county_geojson['features']):
    geo_county['properties']['COUNT'] = {candidate: 0 for candidate in candidates}
    geo_county['properties']['FUNDRAISING'] = {candidate: 0.0 for candidate in candidates}
    
    for county in out_dict.values():
        if county['County'] == geo_county['properties']['NAME'] and county['State_ID'] == geo_county['properties']['STATE']:
            geo_county['properties']['COUNT'] = county['Count']
            geo_county['properties']['FUNDRAISING'] = {k: round(v, 0) for k, v in county['Fundraising'].items()}
            
    
    county_geojson['features'][i] = geo_county

# %%
with open('processed_data/counties.geojson', 'w') as f:
    json.dump(county_geojson, f)

# %%
funds = 0
people = 0

for county in county_geojson['features']:
    for candidate in county['properties']['COUNT'].keys():
        people += county['properties']['COUNT'][candidate]
        funds += county['properties']['FUNDRAISING'][candidate]

print(funds, people, 1.0*funds/people)
# Out:
# 24811682.0 312349 79.4357657620162

# %% [markdown]
# ### Top Zipcodes

# %%
# by_zip = contributions.groupby(['formatted_zip'])['contribution_receipt_amount'].sum().reset_index()
# by_zip.sort_values(['contribution_receipt_amount'])
# by_zip[['formatted_zip', 'contribution_receipt_amount']].head()
